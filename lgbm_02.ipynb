# %%
# Google Colab 환경을 위한 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# === One-Cell Clean Preprocessing (공휴일여부 + 휴무일여부) ===
import pandas as pd
import numpy as np

TRAIN_PATH = '/content/drive/MyDrive/lg_aimers_2/data/train/train.csv'
OUT_PATH   = '/content/drive/MyDrive/lg_aimers_2/train_preprocessed_02.csv'

try:
    import holidays
except ModuleNotFoundError:
    # !pip install holidays -q
    import holidays


def preprocess_data(df: pd.DataFrame) -> pd.DataFrame:
    """train.csv 전처리 + (공휴일/휴무일) + 계절/사이클릭 + 출시일 파생"""
    df = df.copy()
    df['영업일자'] = pd.to_datetime(df['영업일자'])
    df['년'] = df['영업일자'].dt.year
    df['월'] = df['영업일자'].dt.month
    df['일'] = df['영업일자'].dt.day
    df['요일'] = df['영업일자'].dt.dayofweek
    df['주말여부'] = df['요일'].isin([5, 6])

    # 메뉴 분리
    df[['영업장명', '메뉴명']] = df['영업장명_메뉴명'].str.split('_', n=1, expand=True)

    # === 캘린더 피처 ===
    def add_calendar_features(frame: pd.DataFrame, date_col="영업일자") -> pd.DataFrame:
        out = frame.copy()
        d = pd.to_datetime(out[date_col])
        years = sorted(d.dt.year.unique())
        try:
            KR_HOL = holidays.KR(years=years, language="ko")
        except Exception:
            KR_HOL = holidays.KR(years=years)

        # 공휴일 여부만
        out["공휴일여부"] = d.dt.date.map(lambda x: x in KR_HOL)

        # 계절
        m = d.dt.month
        out["계절(겨울0봄1여름2가을3)"] = (
            (m.isin([12,1,2]))*0 +
            (m.isin([3,4,5]))*1 +
            (m.isin([6,7,8]))*2 +
            (m.isin([9,10,11]))*3
        ).astype("int8")

        # 사이클릭
        out["요일_sin"] = np.sin(2*np.pi*out["요일"]/7)
        out["요일_cos"] = np.cos(2*np.pi*out["요일"]/7)
        out["월_sin"]   = np.sin(2*np.pi*(out["월"]-1)/12)
        out["월_cos"]   = np.cos(2*np.pi*(out["월"]-1)/12)

        return out

    df = add_calendar_features(df, date_col='영업일자')

    # === 추가: 휴무일여부 (주말 OR 공휴일) ===
    df["휴무일여부"] = df["주말여부"] | df["공휴일여부"]

    # === 출시일 파생 ===
    launch_dates = {
        '느티나무 셀프BBQ_1인 수저세트': '2023-01-17', '느티나무 셀프BBQ_BBQ55(단체)': '2023-01-05',
        '느티나무 셀프BBQ_대여료 90,000원': '2023-01-02', '느티나무 셀프BBQ_본삼겹 (단품,실내)': '2023-01-03',
        '느티나무 셀프BBQ_스프라이트 (단체)': '2023-01-03', '느티나무 셀프BBQ_신라면': '2023-04-14',
        '느티나무 셀프BBQ_쌈야채세트': '2023-01-11', '느티나무 셀프BBQ_쌈장': '2023-04-14',
        '느티나무 셀프BBQ_육개장 사발면': '2023-04-14', '느티나무 셀프BBQ_일회용 소주컵': '2023-01-23',
        '느티나무 셀프BBQ_일회용 종이컵': '2023-01-22', '느티나무 셀프BBQ_잔디그늘집 대여료 (12인석)': '2023-04-14',
        '느티나무 셀프BBQ_잔디그늘집 대여료 (6인석)': '2023-01-05', '느티나무 셀프BBQ_잔디그늘집 의자 추가': '2023-04-14',
        '느티나무 셀프BBQ_참이슬 (단체)': '2023-01-03', '느티나무 셀프BBQ_친환경 접시 14cm': '2023-01-22',
        '느티나무 셀프BBQ_친환경 접시 23cm': '2023-01-05', '느티나무 셀프BBQ_카스 병(단체)': '2023-01-03',
        '느티나무 셀프BBQ_콜라 (단체)': '2023-01-03', '느티나무 셀프BBQ_햇반': '2023-04-14',
        '느티나무 셀프BBQ_허브솔트': '2023-04-14', '담하_(단체) 공깃밥': '2023-03-13',
        '담하_(단체) 생목살 김치전골 2.0': '2023-09-18', '담하_(단체) 은이버섯 갈비탕': '2023-06-12',
        '담하_(단체) 한우 우거지 국밥': '2023-01-06', '담하_(단체) 황태해장국 3/27까지': '2023-01-07',
        '담하_(정식) 된장찌개': '2023-06-03', '담하_(정식) 물냉면 ': '2023-06-03',
        '담하_(정식) 비빔냉면': '2023-06-03', '담하_(후식) 물냉면': '2023-06-02',
        '담하_(후식) 비빔냉면': '2023-06-02', '담하_갑오징어 비빔밥': '2023-03-17',
        '담하_갱시기': '2023-12-08', '담하_꼬막 비빔밥': '2023-09-08',
        '담하_느린마을 막걸리': '2023-01-02', '담하_담하 한우 불고기 정식': '2023-06-02',
        '담하_더덕 한우 지짐': '2023-09-09', '담하_라면사리': '2023-01-04',
        '담하_룸 이용료': '2023-01-03', '담하_명인안동소주': '2023-07-01',
        '담하_명태회 비빔냉면': '2023-06-02', '담하_문막 복분자 칵테일': '2023-09-12',
        '담하_봉평메밀 물냉면': '2023-06-02', '담하_제로콜라': '2023-01-05',
        '담하_처음처럼': '2023-01-03', '담하_하동 매실 칵테일': '2023-03-18',
        '라그로타_AUS (200g)': '2023-12-08', '라그로타_G-Charge(3)': '2023-01-02',
        '라그로타_Open Food': '2023-01-07', '라그로타_그릴드 비프 샐러드': '2023-09-08',
        '라그로타_까르보나라': '2023-12-08', '라그로타_모둠 해산물 플래터': '2023-09-09',
        '라그로타_미션 서드 카베르네 쉬라': '2023-01-02', '라그로타_버섯 크림 리조또': '2023-12-08',
        '라그로타_시저 샐러드 ': '2023-09-08', '라그로타_알리오 에 올리오 ': '2023-09-08',
        '라그로타_양갈비 (4ps)': '2023-09-10', '라그로타_한우 (200g)': '2023-12-09',
        '라그로타_해산물 토마토 스튜 파스타': '2023-12-08', '미라시아_(단체)브런치주중 36,000': '2023-01-03',
        '미라시아_(오븐) 하와이안 쉬림프 피자': '2023-09-09', '미라시아_BBQ 고기추가': '2023-01-05',
        '미라시아_글라스와인 (레드)': '2023-01-02', '미라시아_레인보우칵테일(알코올)': '2023-01-02',
        '미라시아_버드와이저(무제한)': '2023-04-21', '미라시아_보일링 랍스타 플래터': '2023-06-05',
        '미라시아_보일링 랍스타 플래터(덜매운맛)': '2023-06-03', '미라시아_브런치(대인) 주중': '2023-01-02',
        '미라시아_쉬림프 투움바 파스타': '2023-06-03', '미라시아_스텔라(무제한)': '2023-04-21',
        '미라시아_스프라이트': '2023-06-02', '미라시아_얼그레이 하이볼': '2023-01-02',
        '미라시아_유자 하이볼': '2023-03-17', '미라시아_잭 애플 토닉': '2023-09-09',
        '미라시아_칠리 치즈 프라이': '2023-06-03', '미라시아_코카콜라': '2023-06-02',
        '미라시아_코카콜라(제로)': '2023-06-12', '미라시아_콥 샐러드': '2023-12-08',
        '미라시아_파스타면 추가(150g)': '2023-06-03', '미라시아_핑크레몬에이드': '2023-03-17',
        '연회장_Cass Beer': '2023-01-06', '연회장_Conference L1': '2023-01-03',
        '연회장_Conference L2': '2023-01-11', '연회장_Conference L3': '2023-01-05',
        '연회장_Conference M1': '2023-01-06', '연회장_Conference M8': '2023-01-09',
        '연회장_Conference M9': '2023-01-06', '연회장_Convention Hall': '2023-01-03',
        '연회장_Cookie Platter': '2023-01-09', '연회장_Grand Ballroom': '2023-01-06',
        '연회장_OPUS 2': '2023-01-05', '연회장_Regular Coffee': '2023-02-24',
        '연회장_공깃밥': '2023-07-21', '연회장_마라샹궈': '2023-09-08',
        '연회장_매콤 무뼈닭발&계란찜': '2023-01-02', '연회장_삼겹살추가 (200g)': '2023-07-21',
        '연회장_왕갈비치킨': '2023-07-22', '카페테리아_단체식 13000(신)': '2023-04-18',
        '카페테리아_단체식 18000(신)': '2023-04-05', '카페테리아_진사골 설렁탕': '2023-12-06',
        '카페테리아_한상 삼겹구이 정식(2인) 소요시간 약 15~20분': '2023-03-17',
        '화담숲주막_느린마을 막걸리': '2023-03-31', '화담숲주막_단호박 식혜 ': '2023-03-31',
        '화담숲주막_병천순대': '2023-03-31', '화담숲주막_스프라이트': '2023-03-31',
        '화담숲주막_참살이 막걸리': '2023-03-31', '화담숲주막_찹쌀식혜': '2023-03-31',
        '화담숲주막_콜라': '2023-03-31', '화담숲주막_해물파전': '2023-03-31',
        '화담숲카페_메밀미숫가루': '2023-03-31', '화담숲카페_아메리카노 HOT': '2023-03-31',
        '화담숲카페_아메리카노 ICE': '2023-03-31', '화담숲카페_카페라떼 ICE': '2023-03-31',
        '화담숲카페_현미뻥스크림': '2023-03-31'
    }
    launch_dates = {k: pd.to_datetime(v) for k, v in launch_dates.items()}

    def calculate_days_since_launch(row):
        menu = row['영업장명_메뉴명']
        if menu in launch_dates:
            launch_date = launch_dates[menu]
            if row['영업일자'] >= launch_date:
                return (row['영업일자'] - launch_date).days
        return 0

    df['출시일로부터경과일'] = df.apply(calculate_days_since_launch, axis=1)

    return df


# 실행
train_df = pd.read_csv(TRAIN_PATH)
train_preprocessed = preprocess_data(train_df)
train_preprocessed.to_csv(OUT_PATH, index=False, encoding='utf-8-sig')
print("전처리 완료 →", OUT_PATH)

# 점검
print("공휴일여부 분포:", train_preprocessed["공휴일여부"].value_counts(dropna=False).to_dict())
print("휴무일여부 분포:", train_preprocessed["휴무일여부"].value_counts(dropna=False).to_dict())
# Out:
# 전처리 완료 → /content/drive/MyDrive/lg_aimers_2/train_preprocessed_02.csv
# 공휴일여부 분포: {False: 97079, True: 5597}
# 휴무일여부 분포: {False: 69287, True: 33389}

# %%
# !pip install lightgbm -q

import pandas as pd
import numpy as np
from lightgbm import LGBMRegressor, log_evaluation, early_stopping
from sklearn.metrics import mean_squared_error
import joblib, os

TRAIN_PATH = "/content/drive/MyDrive/lg_aimers_2/train_preprocessed_02.csv"

# 1) Load
df = pd.read_csv(TRAIN_PATH, parse_dates=["영업일자"])

# 2) 기본 타입 정리 (★ 휴무일여부 추가)
bool_cols = ["주말여부","공휴일여부","휴무일여부","신규메뉴여부"]
bool_cols = [c for c in bool_cols if c in df.columns]
for c in bool_cols:
    df[c] = df[c].astype(int)

# 원-소스 카테고리
key_col = "영업장명_메뉴명"
if key_col not in df.columns:
    raise ValueError(f"'{key_col}' 컬럼이 필요합니다.")
df[key_col] = df[key_col].astype("category")

# 3) 누수 방지용 시계열 정렬 후 lag/rolling 생성
df = df.sort_values([key_col, "영업일자"]).copy()

lag_list = [1, 7, 14, 28]
for lag in lag_list:
    df[f"lag_{lag}"] = df.groupby(key_col)["매출수량"].shift(lag)

# rolling
def add_rolling(g, window, how="mean"):
    s = g["매출수량"].shift(1)
    if how == "mean":
        return s.rolling(window, min_periods=1).mean()
    elif how == "sum":
        return s.rolling(window, min_periods=1).sum()

df["roll7_mean"]  = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="mean")
df["roll7_sum"]   = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="sum")
df["roll14_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=14, how="mean")
df["roll28_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=28, how="mean")

# 같은 요일 패턴
def same_dow_mean_28(g):
    out = np.full(len(g), np.nan, dtype=float)
    vals = g["매출수량"].shift(1)
    dows = g["요일"]
    for i in range(len(g)):
        lo = max(0, i-28)
        same_idx = [j for j in range(lo,i) if dows.iloc[j]==dows.iloc[i]]
        if same_idx:
            out[i] = vals.iloc[same_idx].mean()
    return pd.Series(out, index=g.index)

if "요일" in df.columns:
    df["same_dow_mean_28"] = df.groupby(key_col, group_keys=False).apply(same_dow_mean_28)

# 신규 메뉴 추가 파생
if "출시일로부터경과일" in df.columns:
    df["출시후_주차"] = (df["출시일로부터경과일"] // 7).clip(lower=0).astype(int)
    df["출시_0주"]     = (df["출시후_주차"] == 0).astype(int)
    df["출시_1_2주"]   = df["출시후_주차"].between(1,2).astype(int)
    df["출시_3_4주"]   = df["출시후_주차"].between(3,4).astype(int)
    df["출시_5주이상"] = (df["출시후_주차"] >= 5).astype(int)

# 4) Train/Valid split
train_cut   = pd.Timestamp("2024-05-31")
valid_start = pd.Timestamp("2024-06-01")
valid_end   = pd.Timestamp("2024-06-15")

train_df = df[df["영업일자"] <= train_cut].copy()
valid_df = df[(df["영업일자"] >= valid_start) & (df["영업일자"] <= valid_end)].copy()

# 사용 피처 (★ 휴무일여부 추가)
base_feats = [c for c in [
    "년","월","일","요일",
    "주말여부","공휴일여부","휴무일여부","신규메뉴여부",
    "출시일로부터경과일","출시후_주차",
    "출시_0주","출시_1_2주","출시_3_4주","출시_5주이상",
    "요일_sin","요일_cos","월_sin","월_cos","계절(겨울0봄1여름2가을3)"
] if c in df.columns]

lag_feats  = [f"lag_{l}" for l in lag_list]
roll_feats = [c for c in ["roll7_mean","roll7_sum","roll14_mean","roll28_mean","same_dow_mean_28"] if c in df.columns]

use_cols = base_feats + lag_feats + roll_feats + [key_col]

# NA drop & fill
train_df = train_df.dropna(subset=[f"lag_{min(lag_list)}"])
valid_df = valid_df.dropna(subset=[f"lag_{min(lag_list)}"])
fill_cols = list(set(use_cols) - {key_col})
train_df[fill_cols] = train_df[fill_cols].fillna(0)
valid_df[fill_cols] = valid_df[fill_cols].fillna(0)

X_trn, y_trn = train_df[use_cols], train_df["매출수량"].astype(float).values
X_val, y_val = valid_df[use_cols], valid_df["매출수량"].astype(float).values

# LightGBM
cat_features = [use_cols.index(key_col)]
lgbm = LGBMRegressor(
    objective="regression",
    n_estimators=3000,
    learning_rate=0.03,
    max_depth=-1,
    num_leaves=127,
    subsample=0.9,
    colsample_bytree=0.9,
    reg_lambda=1.0,
    random_state=42,
    n_jobs=-1
)
lgbm.fit(
    X_trn, y_trn,
    eval_set=[(X_val, y_val)],
    eval_metric="rmse",
    categorical_feature=cat_features,
    callbacks=[log_evaluation(period=200), early_stopping(stopping_rounds=200)]
)

# 검증 성능
val_pred = lgbm.predict(X_val, num_iteration=lgbm.best_iteration_)
rmse = np.sqrt(mean_squared_error(y_val, val_pred))
print(f"[VALID] RMSE: {rmse:,.4f}")

# 중요도 & 저장
imp = pd.DataFrame({"feature": use_cols, "importance": lgbm.feature_importances_}).sort_values("importance", ascending=False)
os.makedirs("/content/drive/MyDrive/lg_aimers_2/models", exist_ok=True)
joblib.dump({"model": lgbm, "features": use_cols, "cat_idx": cat_features},
            "/content/drive/MyDrive/lg_aimers_2/models/lgbm_02_menu_demand.pkl")
imp.to_csv("/content/drive/MyDrive/lg_aimers_2/models/lgbm_02_feature_importance.csv", index=False)

print("모델 저장 완료")
print("상위 중요도:\n", imp.head(15))
# Out:
# /tmp/ipython-input-3401797064.py:31: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f"lag_{lag}"] = df.groupby(key_col)["매출수량"].shift(lag)
# /tmp/ipython-input-3401797064.py:31: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f"lag_{lag}"] = df.groupby(key_col)["매출수량"].shift(lag)
# /tmp/ipython-input-3401797064.py:31: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f"lag_{lag}"] = df.groupby(key_col)["매출수량"].shift(lag)
# /tmp/ipython-input-3401797064.py:31: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f"lag_{lag}"] = df.groupby(key_col)["매출수량"].shift(lag)
# /tmp/ipython-input-3401797064.py:41: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["roll7_mean"]  = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="mean")
# /tmp/ipython-input-3401797064.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df["roll7_mean"]  = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="mean")
# /tmp/ipython-input-3401797064.py:42: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["roll7_sum"]   = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="sum")
# /tmp/ipython-input-3401797064.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df["roll7_sum"]   = df.groupby(key_col, group_keys=False).apply(add_rolling, window=7, how="sum")
# /tmp/ipython-input-3401797064.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["roll14_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=14, how="mean")
# /tmp/ipython-input-3401797064.py:43: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df["roll14_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=14, how="mean")
# /tmp/ipython-input-3401797064.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["roll28_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=28, how="mean")
# /tmp/ipython-input-3401797064.py:44: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df["roll28_mean"] = df.groupby(key_col, group_keys=False).apply(add_rolling, window=28, how="mean")
# /tmp/ipython-input-3401797064.py:59: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df["same_dow_mean_28"] = df.groupby(key_col, group_keys=False).apply(same_dow_mean_28)
# /tmp/ipython-input-3401797064.py:59: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df["same_dow_mean_28"] = df.groupby(key_col, group_keys=False).apply(same_dow_mean_28)
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009793 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2925
# [LightGBM] [Info] Number of data points in the train set: 99588, number of used features: 28
# [LightGBM] [Info] Start training from score 10.723581
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's rmse: 15.3074	valid_0's l2: 234.318
# [400]	valid_0's rmse: 14.9919	valid_0's l2: 224.757
# [600]	valid_0's rmse: 14.8611	valid_0's l2: 220.851
# [800]	valid_0's rmse: 14.8051	valid_0's l2: 219.192
# [1000]	valid_0's rmse: 14.7633	valid_0's l2: 217.956
# [1200]	valid_0's rmse: 14.7491	valid_0's l2: 217.535
# [1400]	valid_0's rmse: 14.7484	valid_0's l2: 217.515
# Early stopping, best iteration is:
# [1273]	valid_0's rmse: 14.7349	valid_0's l2: 217.118
# [VALID] RMSE: 14.7349
# 모델 저장 완료
# 상위 중요도:
#               feature  importance
# 18             lag_1       16985
# 19             lag_7       15822
# 2                  일       14624
# 26  same_dow_mean_28       13040
# 20            lag_14       12141
# 21            lag_28       10447
# 22        roll7_mean       10340
# 24       roll14_mean        8826
# 25       roll28_mean        8737
# 7          출시일로부터경과일        8606
# 27          영업장명_메뉴명        8352
# 23         roll7_sum        4973
# 3                 요일        4896
# 1                  월        4323
# 13            요일_sin        3552

# %%
# !pip install lightgbm -q
import os, glob, joblib
import numpy as np
import pandas as pd
from lightgbm import LGBMRegressor

# ===== 경로 설정 =====
MODEL_PATH   = "/content/drive/MyDrive/lg_aimers_2/models/lgbm_02_menu_demand.pkl"
TEST_DIR     = "/content/drive/MyDrive/lg_aimers_2/data/test"   # TEST_00.csv ~ TEST_09.csv
SAMPLE_PATH  = "/content/drive/MyDrive/lg_aimers_2/data/sample_submission.csv"  # 필요 시 수정
OUT_PATH     = "/content/drive/MyDrive/lg_aimers_2/submission_lightgbm_02.csv"

# ===== 모델 로드 =====
bundle = joblib.load(MODEL_PATH)
model: LGBMRegressor = bundle["model"]
use_cols = bundle["features"]
cat_idx  = bundle["cat_idx"]
cat_col  = use_cols[cat_idx[0]]

# ===== 공휴일 계산: holidays 라이브러리 사용 =====
try:
    import holidays
except ModuleNotFoundError:
    # Colab 등에서 미설치 시
    import sys, subprocess
    subprocess.run([sys.executable, "-m", "pip", "install", "holidays", "-q"], check=True)
    import holidays

# 연도별 캐시(테스트 파일마다 연도가 다를 수 있으므로 지연 생성)
_HOL_CACHE = {}
def is_holiday(ts: pd.Timestamp) -> bool:
    y = int(ts.year)
    if y not in _HOL_CACHE:
        try:
            _HOL_CACHE[y] = holidays.KR(years=[y], language="ko")
        except Exception:
            _HOL_CACHE[y] = holidays.KR(years=[y])
    return ts.date() in _HOL_CACHE[y]

# ===== 출시 정보 (전처리와 동일 규칙 사용: dict 기반) =====
launch_dates = {
    '느티나무 셀프BBQ_1인 수저세트': '2023-01-17', '느티나무 셀프BBQ_BBQ55(단체)': '2023-01-05',
    '느티나무 셀프BBQ_대여료 90,000원': '2023-01-02', '느티나무 셀프BBQ_본삼겹 (단품,실내)': '2023-01-03',
    '느티나무 셀프BBQ_스프라이트 (단체)': '2023-01-03', '느티나무 셀프BBQ_신라면': '2023-04-14',
    '느티나무 셀프BBQ_쌈야채세트': '2023-01-11', '느티나무 셀프BBQ_쌈장': '2023-04-14',
    '느티나무 셀프BBQ_육개장 사발면': '2023-04-14', '느티나무 셀프BBQ_일회용 소주컵': '2023-01-23',
    '느티나무 셀프BBQ_일회용 종이컵': '2023-01-22', '느티나무 셀프BBQ_잔디그늘집 대여료 (12인석)': '2023-04-14',
    '느티나무 셀프BBQ_잔디그늘집 대여료 (6인석)': '2023-01-05', '느티나무 셀프BBQ_잔디그늘집 의자 추가': '2023-04-14',
    '느티나무 셀프BBQ_참이슬 (단체)': '2023-01-03', '느티나무 셀프BBQ_친환경 접시 14cm': '2023-01-22',
    '느티나무 셀프BBQ_친환경 접시 23cm': '2023-01-05', '느티나무 셀프BBQ_카스 병(단체)': '2023-01-03',
    '느티나무 셀프BBQ_콜라 (단체)': '2023-01-03', '느티나무 셀프BBQ_햇반': '2023-04-14',
    '느티나무 셀프BBQ_허브솔트': '2023-04-14', '담하_(단체) 공깃밥': '2023-03-13',
    '담하_(단체) 생목살 김치전골 2.0': '2023-09-18', '담하_(단체) 은이버섯 갈비탕': '2023-06-12',
    '담하_(단체) 한우 우거지 국밥': '2023-01-06', '담하_(단체) 황태해장국 3/27까지': '2023-01-07',
    '담하_(정식) 된장찌개': '2023-06-03', '담하_(정식) 물냉면 ': '2023-06-03',
    '담하_(정식) 비빔냉면': '2023-06-03', '담하_(후식) 물냉면': '2023-06-02',
    '담하_(후식) 비빔냉면': '2023-06-02', '담하_갑오징어 비빔밥': '2023-03-17',
    '담하_갱시기': '2023-12-08', '담하_꼬막 비빔밥': '2023-09-08',
    '담하_느린마을 막걸리': '2023-01-02', '담하_담하 한우 불고기 정식': '2023-06-02',
    '담하_더덕 한우 지짐': '2023-09-09', '담하_라면사리': '2023-01-04',
    '담하_룸 이용료': '2023-01-03', '담하_명인안동소주': '2023-07-01',
    '담하_명태회 비빔냉면': '2023-06-02', '담하_문막 복분자 칵테일': '2023-09-12',
    '담하_봉평메밀 물냉면': '2023-06-02', '담하_제로콜라': '2023-01-05',
    '담하_처음처럼': '2023-01-03', '담하_하동 매실 칵테일': '2023-03-18',
    '라그로타_AUS (200g)': '2023-12-08', '라그로타_G-Charge(3)': '2023-01-02',
    '라그로타_Open Food': '2023-01-07', '라그로타_그릴드 비프 샐러드': '2023-09-08',
    '라그로타_까르보나라': '2023-12-08', '라그로타_모둠 해산물 플래터': '2023-09-09',
    '라그로타_미션 서드 카베르네 쉬라': '2023-01-02', '라그로타_버섯 크림 리조또': '2023-12-08',
    '라그로타_시저 샐러드 ': '2023-09-08', '라그로타_알리오 에 올리오 ': '2023-09-08',
    '라그로타_양갈비 (4ps)': '2023-09-10', '라그로타_한우 (200g)': '2023-12-09',
    '라그로타_해산물 토마토 스튜 파스타': '2023-12-08',
    '미라시아_(단체)브런치주중 36,000': '2023-01-03',
    '미라시아_(오븐) 하와이안 쉬림프 피자': '2023-09-09', '미라시아_BBQ 고기추가': '2023-01-05',
    '미라시아_글라스와인 (레드)': '2023-01-02', '미라시아_레인보우칵테일(알코올)': '2023-01-02',
    '미라시아_버드와이저(무제한)': '2023-04-21', '미라시아_보일링 랍스타 플래터': '2023-06-05',
    '미라시아_보일링 랍스타 플래터(덜매운맛)': '2023-06-03', '미라시아_브런치(대인) 주중': '2023-01-02',
    '미라시아_쉬림프 투움바 파스타': '2023-06-03', '미라시아_스텔라(무제한)': '2023-04-21',
    '미라시아_스프라이트': '2023-06-02', '미라시아_얼그레이 하이볼': '2023-01-02',
    '미라시아_유자 하이볼': '2023-03-17', '미라시아_잭 애플 토닉': '2023-09-09',
    '미라시아_칠리 치즈 프라이': '2023-06-03', '미라시아_코카콜라': '2023-06-02',
    '미라시아_코카콜라(제로)': '2023-06-12', '미라시아_콥 샐러드': '2023-12-08',
    '미라시아_파스타면 추가(150g)': '2023-06-03', '미라시아_핑크레몬에이드': '2023-03-17',
    '연회장_Cass Beer': '2023-01-06', '연회장_Conference L1': '2023-01-03',
    '연회장_Conference L2': '2023-01-11', '연회장_Conference L3': '2023-01-05',
    '연회장_Conference M1': '2023-01-06', '연회장_Conference M8': '2023-01-09',
    '연회장_Conference M9': '2023-01-06', '연회장_Convention Hall': '2023-01-03',
    '연회장_Cookie Platter': '2023-01-09', '연회장_Grand Ballroom': '2023-01-06',
    '연회장_OPUS 2': '2023-01-05', '연회장_Regular Coffee': '2023-02-24',
    '연회장_공깃밥': '2023-07-21', '연회장_마라샹궈': '2023-09-08',
    '연회장_매콤 무뼈닭발&계란찜': '2023-01-02', '연회장_삼겹살추가 (200g)': '2023-07-21',
    '연회장_왕갈비치킨': '2023-07-22', '카페테리아_단체식 13000(신)': '2023-04-18',
    '카페테리아_단체식 18000(신)': '2023-04-05', '카페테리아_진사골 설렁탕': '2023-12-06',
    '카페테리아_한상 삼겹구이 정식(2인) 소요시간 약 15~20분': '2023-03-17',
    '화담숲주막_느린마을 막걸리': '2023-03-31', '화담숲주막_단호박 식혜 ': '2023-03-31',
    '화담숲주막_병천순대': '2023-03-31', '화담숲주막_스프라이트': '2023-03-31',
    '화담숲주막_참살이 막걸리': '2023-03-31', '화담숲주막_찹쌀식혜': '2023-03-31',
    '화담숲주막_콜라': '2023-03-31', '화담숲주막_해물파전': '2023-03-31',
    '화담숲카페_메밀미숫가루': '2023-03-31', '화담숲카페_아메리카노 HOT': '2023-03-31',
    '화담숲카페_아메리카노 ICE': '2023-03-31', '화담숲카페_카페라떼 ICE': '2023-03-31',
    '화담숲카페_현미뻥스크림': '2023-03-31'
}
launch_dates = {k: pd.to_datetime(v) for k, v in launch_dates.items()}

def add_future_meta_row(date, key):
    """모델 입력 피처(학습 시 사용한 use_cols 기준)와 일치하도록 미래 1행 메타 피처 생성"""
    row = pd.DataFrame({"영업일자":[pd.Timestamp(date)], "영업장명_메뉴명":[key]})
    d = row.loc[0, "영업일자"]

    # 기본 달력
    row["년"] = d.year
    row["월"] = d.month
    row["일"] = d.day
    row["요일"] = d.dayofweek
    row["주말여부"] = int(row.loc[0,"요일"] in [5,6])

    # 공휴일 & 휴무일
    hol = is_holiday(d)
    row["공휴일여부"] = int(hol)
    row["휴무일여부"] = int(hol or bool(row.loc[0,"주말여부"]))

    # 사이클릭
    row["요일_sin"] = np.sin(2*np.pi*row.loc[0,"요일"]/7.0)
    row["요일_cos"] = np.cos(2*np.pi*row.loc[0,"요일"]/7.0)
    row["월_sin"]   = np.sin(2*np.pi*(row.loc[0,"월"]-1)/12.0)
    row["월_cos"]   = np.cos(2*np.pi*(row.loc[0,"월"]-1)/12.0)

    # 계절
    m = row.loc[0,"월"]
    if m in [12,1,2]:
        season = 0
    elif m in [3,4,5]:
        season = 1
    elif m in [6,7,8]:
        season = 2
    else:
        season = 3
    row["계절(겨울0봄1여름2가을3)"] = np.int8(season)

    # 출시 파생
    row["신규메뉴여부"] = int(key in launch_dates)
    if key in launch_dates and d >= launch_dates[key]:
        row["출시일로부터경과일"] = int((d - launch_dates[key]).days)
    else:
        row["출시일로부터경과일"] = 0

    # 출시 후 주차 & 더미 (학습 시 사용했다면 동일하게)
    row["출시후_주차"] = (row["출시일로부터경과일"] // 7)
    row["출시_0주"]   = (row["출시후_주차"] == 0).astype(int)
    row["출시_1_2주"] = row["출시후_주차"].between(1,2).astype(int)
    row["출시_3_4주"] = row["출시후_주차"].between(3,4).astype(int)
    row["출시_5주이상"] = (row["출시후_주차"] >= 5).astype(int)

    return row

def predict_group_autoreg(g: pd.DataFrame):
    key = g[cat_col].iloc[0]
    g = g.sort_values("영업일자").copy()
    g = g.dropna(subset=["매출수량"])
    assert len(g) >= 28, f"{key}: 28일 히스토리 부족"

    hist_vals = g["매출수량"].values.tolist()[-28:]
    hist_dates = g["영업일자"].tolist()[-28:]
    last_date = g["영업일자"].max()
    preds = []

    for h in range(1, 8):
        cur_date = last_date + pd.Timedelta(days=h)
        row = add_future_meta_row(cur_date, key)

        # lags
        def lag(n): return hist_vals[-n] if len(hist_vals) >= n else np.nan
        row["lag_1"], row["lag_7"], row["lag_14"], row["lag_28"] = lag(1), lag(7), lag(14), lag(28)

        # rolling (과거값만)
        def rmean(n):
            arr = hist_vals[-n:] if len(hist_vals) else []
            return float(np.mean(arr)) if arr else 0.0
        def rsum(n):
            arr = hist_vals[-n:] if len(hist_vals) else []
            return float(np.sum(arr)) if arr else 0.0
        row["roll7_mean"], row["roll7_sum"], row["roll14_mean"], row["roll28_mean"] = \
            rmean(7), rsum(7), rmean(14), rmean(28)

        # 같은 요일 평균(최근 28일 범위)
        cur_dow = cur_date.dayofweek
        hist_dows = [pd.Timestamp(d).dayofweek for d in hist_dates]
        same_idx = [i for i in range(len(hist_vals)) if hist_dows[i] == cur_dow]
        row["same_dow_mean_28"] = float(np.mean([hist_vals[i] for i in same_idx])) if same_idx else 0.0

        # 모델 입력 정렬
        X = row.reindex(columns=use_cols).copy()
        X[cat_col] = X[cat_col].astype("category")
        for c in X.columns:
            if c != cat_col:
                X[c] = X[c].fillna(0)

        yhat = float(model.predict(X, num_iteration=getattr(model, "best_iteration_", None))[0])
        yhat = max(0.0, yhat)  # 음수 방지
        preds.append(yhat)

        # autoreg 업데이트
        hist_vals.append(yhat); hist_dates.append(cur_date)
        if len(hist_vals) > 28:
            hist_vals, hist_dates = hist_vals[-28:], hist_dates[-28:]

    return preds  # 길이 7

# ===== 샘플 제출 파일 불러오기 =====
sub = pd.read_csv(SAMPLE_PATH)
menu_cols = [c for c in sub.columns if c != "영업일자"]

# ===== TEST 파일 순회 =====
test_files = sorted(glob.glob(os.path.join(TEST_DIR, "TEST_*.csv")))
print("Found:", test_files)

for f in test_files:
    test_name = os.path.splitext(os.path.basename(f))[0]  # TEST_00
    test_id = test_name.split("_")[1]                     # 00
    df = pd.read_csv(f, parse_dates=["영업일자"])

    # 타입/정렬
    if cat_col in df.columns:
        df[cat_col] = df[cat_col].astype("category")
    df = df.sort_values([cat_col, "영업일자"]).copy()

    # 메뉴 단위 예측
    for key, g in df.groupby(cat_col, observed=True):
        preds7 = predict_group_autoreg(g)

        # 제출 파일에 해당 메뉴 열이 없으면 skip
        if key not in menu_cols:
            continue

        # +1~+7일 채우기
        for k in range(1, 8):
            ridx = sub.index[sub["영업일자"] == f"{test_name}+{k}일"]
            if len(ridx) == 1:
                sub.loc[ridx[0], key] = preds7[k-1]

# (선택) 후처리
# sub[menu_cols] = sub[menu_cols].clip(lower=0).round(4)

# ===== 저장 =====
sub.to_csv(OUT_PATH, index=False, encoding="utf-8-sig")
print("Saved submission ->", OUT_PATH)
# Out:
# Found: ['/content/drive/MyDrive/lg_aimers_2/data/test/TEST_00.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_01.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_02.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_03.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_04.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_05.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_06.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_07.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_08.csv', '/content/drive/MyDrive/lg_aimers_2/data/test/TEST_09.csv']
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.902202500170592' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.389887208849555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.00363331786598' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2286045658030194' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.083252003572336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2423188884858105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6794549457817092' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5089949090423054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.8166692704156' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1234531034809636' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3325848662984624' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9536888715094061' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6839910199498196' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.555822876267509' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.033417755269475' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3316676998206538' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9395349454432593' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9478202505721223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4761520300509008' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7385885449244318' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.03361485479994' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.566096513657377' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4418212572563232' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11778023884236435' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6374063718469873' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.219718410092292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8596044432038554' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.592002677831545' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.750334814602285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.678779702592446' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9920262797052342' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7450253735622496' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.548656425504361' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4392663031499526' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.27031931117327435' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.011194156203904827' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.615981193439538' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.12227859080205628' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0806585433140625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.40872507485686' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.345038960386946' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6327363134768953' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0648730377836814' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0070045945163075' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.47064332354502675' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3208310287869645' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3910525548237862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8910485671372887' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.43907535834261013' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.302463410602878' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.647552017474638' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6062719297049124' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.8932365491746355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0963384607038504' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7102269650972307' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7882725021336023' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.492004005742272' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.08744528342189163' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0279587275302269' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8445641261964056' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.971876153246301' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.638828343896773' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.54141984026432' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.940163376231053' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.10674166493615' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0415800542845455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2016782727005124' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5296736673355273' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.425084995623505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.618815133730427' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.782096972297102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.562400698850653' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2503198439207276' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2159176031776533' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4387051165969558' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3082874727385425' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.44697677396597335' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.547558323028758' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6338082276764094' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.52060923494834' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.372839395122497' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9301229181125731' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.32746758978043183' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8152061945883458' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2153057207019007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2873991463781715' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.065311751063458' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.215595718703105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.867725052171102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.586130481150233' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5784983591050215' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9658875892074954' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9890957863429295' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.800778216787084' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1313901738521263' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.43331170535512925' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0416116777141908' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7751501581736959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.330554266767102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.8402392591282615' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7336159515582514' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.20693717957330715' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2696593267727536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5862244790017379' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '141.42206947338255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.447016773701017' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '35.98592761953404' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2213327319456653' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5938262773579908' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6867690948694883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3718471163478125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6637926469847806' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1611867041533517' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7919594923401494' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.29218838690675936' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6159659120549748' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6899872222806545' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5368253822128473' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3705554487746339' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6179079659730529' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9549282372756351' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9325999722576445' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8507482658753629' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8338503725412736' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.36917184694745125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8967473762037323' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7909385886658831' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8875761372612541' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5214185315755836' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.430723668468717' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1207008111598684' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3626263066946604' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '25.7396462485834' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0975631940560844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9243514312213222' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3306149070037243' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.068057351026975' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.007724272180143951' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.720214449262458' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.723413021713694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0940443927151255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5018920462475018' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6359473346422329' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.027290793750602126' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.697016782971982' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.015557520092279564' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.58842340936784' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.51796158278764' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.474676757270187' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.16073604914786604' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.807361486887348' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07570898634402673' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07030435986513914' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.543187714749024' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.05077776485035742' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.41303808524548324' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.103425024047382' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.459261790531549' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.93733239873673' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.02730533401134032' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.607651934603014' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6845706755287182' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.010813540666142' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0112486098465352' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.703879383208131' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.09485794518654786' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.04765709617881426' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.685784360234928' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.021088480779854504' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2273646933601483' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7050097373945855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.391693363619488' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.431172882093566' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.760035868486247' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.2145994688045' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7727498612879042' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07199629953681967' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0127144972438538' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.48407720240185' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.820549939752831' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.96776996021997' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.443061850529054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.56540367277688' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.044364964703277' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.65061069525901' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.640431560209436' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.082396566074612' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '54.979770770392676' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '58.94827483070216' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.804122200170534' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '45.13696510468728' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.045013379359581' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# /tmp/ipython-input-1078738562.py:238: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.54050735021392' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sub.loc[ridx[0], key] = preds7[k-1]
# Saved submission -> /content/drive/MyDrive/lg_aimers_2/submission_lightgbm_02.csv
